# %% [markdown]
# Camilo Garcia Torres
# 201417471
#
#
#  # <div style="text-align: center">Taller 3 </div> #
#
# ## Objetivos :##
#
# - Familializarse con los archivos VBOX e implementar una funcion para la lectura de estos.
# - Comparar el rendimiento del kart (archivos VBOX) de combustion contra el kart electrico en terminos de tiempo de vuelta, aceleracion y velocidad.
# - Analizar el desempeño de los motores tanto de combustion como electrico (momento par, velocidad angular y potencia) y comparar
# - Sugerir mejoras al carro electrico
#
# ## Funciones :##

# %%
# %pylab inline
#from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import numpy as np
import string
import matplotlib.cm as cm
import os
from scipy import ndimage
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rll=0.139 # Radio geométrico de las llantas en traseras (m)
refc=0.98*rll # Radio efectivo llantas traseras (m)
rin=0.0631 #radio interno del neumático (m)
rlld=0.129 # Radio llantas delanteras (m)
rind=0.0631 # Radio rin llantas delanteras (m)

# Datos Transmisión
dp=11 # Dientes del piñon
dpl=39 # Dientes del plato
ng=dpl/dp # Relación de Transmisión
etaf=0.95 # Eficiencia de transmisión

# Datos eje llantas
reje=0.02 # Radio eje de las llantas (m)
meje=3.832 # Masa del eje (kg)

# Datos Kart general
masa=152.0 # masa del Kart (kg)
g=9.81 # Gravedad (m/s)
w=masa*g # peso del Kart (N)

# Datos Fuerzas de la fórmula de aceleración
rho=1.1955 # densidad del aire (kg/m^3)
dll=0.975 # Distancia entre ejes de llantas delanteras (m)
alj=0.88 # Altura con el piloto sentado en el kart (estatura 1.68 m) (m)
af=(dll*alj)/2 # Area Frontal Kart (m^2)
cd=0.89 # Coeficiente de Arrastre Kart
vw=0.0 # velocidad del viento (m/s)
theta=0.0 # Angulo carretera

# Inercias
ii=5.2E-3 # Inercia motor de combustión (kg m^2) 

mllt=1.43 # Masa llantas traseras (kg)
mlld=1.20 # Masa llantas delanteras (kg)

mbt=0.7*mllt # El porcentaje de la masa total que pesa la parte "banda" de la llanta trasera
mdt=0.3*mllt # El porcentaje de la masa total que pesa la parte "disco" de la llanta trasera
mbd=0.7*mlld # El porcentaje de la masa total que pesa la parte "banda" de la llanta delantera
mdd=0.3*mlld # El porcentaje de la masa total que pesa la parte "disco" de la llanta delantera
illd=(mbd*rlld)+(mdd*(rlld**2-rind**2))/2 # Inercia 1 llanta delantera (kg-m^2)
illt=(mbt*rll)+(mdt*(rll**2-rin**2))/2 # Inercia 1 llanta trasera (kg-m^2)

#paso=7.62 #(mm)
#rpim= paso*(0.6+(1/tan(180/dp))) # Radio Piñon (mm)
#rplam=paso*(0.6+(1/tan(180/dpl))) # Radio Plato (mm)
#rpi= rpim/1000 #Radio Piñon (m)
#rpla= rplam/1000 #Radio Plato (m)
rpi=0.01525#(m)
rpla=0.04096 #(m)
rhoac=7850.0 # Densidad del Acero (kg/m^3)
bpi=0.01 # Ancho piñon (m)
bpla=0.02 # Ancho plato (m)
vpi= bpi*np.pi*rpi**2 # Volumen del piñon (m^3)
vpla=bpla*np.pi*rpla**2 # Volumen del plato (m^3)
mpi=rhoac*vpi # Masa del piñon (kg)
mpla=rhoac*vpla # Masa del plato (kg)
ig=((mpi*(rpi**2))/2.0)+((mpla*(rpla**2))/2.0) # Inercia de la transmisión (kg-m^2)
 

ieje=(meje*reje**2)/2.0 # Inercia del eje de las llantas (kg-m^2)

# Fuerzas Aceleración
# Resistencia a la rodadura
a=0.2231 # Distancia del centro de gravedad al eje de la llanta trasera (m)
l=1.0063 # Distancia de eje de las llantas traseras y delanteras (m)
h=0.07478 # Altura del centro de gravedad del kart con respecto al piso (m)

gamma = 1 # aceleracion

# Aceleración, Fuerza de tracción
mr=((((ii-ig)*ng**2))+ieje+illd*2+illt*2)/(refc**2)

# %% [markdown]
# <div style="text-align: justify"> 1. Despues de agregar las librerias y las constantes del carro se realiza la funcion que lea archivos de VBOX, esta funcion sirve para los 2 tipos de archivo vbox con los que cuenta la universidad. La funcion tiene como entrada solo 2 cosas: la carpeta donde se encuentra el archivo y el nombre del archivo. Para este caso la carpeta solo tiene 2 opciones: data para datos de carro de combustion interna y data electrico para datos de carro electrico.</div>

# %%
def datosVBOX (base_dir,data_file):

    #base_dir = 'data_electrico'
    with open(os.path.join(base_dir,data_file), 'r', encoding='cp1252') as vboxdata:
        section = []
        time = []
        lat = []
        long = []
        vel = []
        height = []
        vertv = []
        for line in vboxdata:
            if line[0] == '[':
                section = str.replace(line, "\n","")
                continue
            if section == '[column names]':
                col_names = str.replace(line, "  \n","").split('  ')
                section = []
            if section == '[data]':
                linesplit = str.replace(line, " \n","").split(' ')
                time.append(float(linesplit[1][0:2])*3600+float(linesplit[1][2:4])*60+float(linesplit[1][4:]))
                lat.append(float(linesplit[2]))
                long.append(float(linesplit[3]))
                vel.append(float(linesplit[4]))
                height.append(float(linesplit[6]))
                vertv.append(float(linesplit[7]))

    time = np.asarray(time)
    lat = np.asarray(lat)
    long = np.asarray(long)
    vel = np.asarray(vel)*(1000/3600)
    height = np.asarray(height)
    vertv = np.asarray(vertv)
    time_base = time[0]
    time = time - time_base
    lat = lat/60.0
    long = -long/60.0
    dt = time[1]-time[0]
    datos = {"Tiempo":time, "Latitud":lat, "Longitud":long,"Velocidad":vel,"Altura":height, "dt":dt}
    tabladatos= pd.DataFrame(datos)
    return tabladatos

# %%
x=datosVBOX('data_electrico','VBS__047.VBO')
x
# Out:
#        Altura   Latitud   Longitud  Tiempo  Velocidad    dt
# 0     2592.62  4.962753 -73.949734    0.00   0.241667  0.05
# 1     2592.64  4.962753 -73.949734    0.05   0.275000  0.05
# 2     2592.65  4.962753 -73.949734    0.10   0.236111  0.05
# 3     2592.65  4.962753 -73.949734    0.15   0.186111  0.05
# 4     2592.65  4.962753 -73.949734    0.20   0.163889  0.05
# 5     2592.66  4.962753 -73.949734    0.25   0.169444  0.05
# 6     2592.66  4.962753 -73.949734    0.30   0.236111  0.05
# 7     2592.66  4.962753 -73.949734    0.35   0.288889  0.05
# 8     2592.66  4.962753 -73.949734    0.40   0.236111  0.05
# 9     2592.66  4.962753 -73.949734    0.45   0.166667  0.05
# 10    2592.66  4.962753 -73.949734    0.50   0.147222  0.05
# 11    2592.65  4.962753 -73.949734    0.55   0.141667  0.05
# 12    2592.64  4.962753 -73.949734    0.60   0.130556  0.05
# 13    2592.63  4.962753 -73.949734    0.65   0.133333  0.05
# 14    2592.62  4.962753 -73.949734    0.70   0.186111  0.05
# ...

# %% [markdown]
# <div style="text-align: justify"> 2. En segunda instanca se definiran las funciones necesarias para Comparar el rendimiento del vehículo de combustión interna (datos Córdoba) con el del kart eléctrico (datos adjuntos) en términos de tiempo de vuelta, velocidades instantáneas, aceleraciones. Se definira esta seccion en 3 partes: La primera es una funcion de cortar datos, para analizar solo una parte de la lista de datos disponible debido a que hay datos que no sirven o para analizar solo una vuelta en cada caso. La segunda parte es la definicion de fuerzas y aceleraciones y la definicion de la funcion acelyvel, la cual retorna los la distancia recorrida en terminos de latitud y longitud, la grafica de velocidad contra tiempo, aceleracion contra tiempo y tiempo de vuelta del proceso. Por ultimo, la tercer parte se centra en la funcion TyP la cual se centra en las caracteristicas principales del motor del kart en terminos de torque, velocidad angular y potencia. </div>

# %%
def cortardatos(basedir,data,i0,i1):

    x=datosVBOX(basedir,data)
    
    timef = x['Tiempo'][i0:i1]-x['Tiempo'][i0]
    latf = x['Latitud'][i0:i1]
    longf = x['Longitud'][i0:i1]
    velf = x['Velocidad'][i0:i1]
    heightf = x['Altura'][i0:i1]
    dt=x['Tiempo'][1]-x['Tiempo'][0]
    datosf = {"Tiempo":timef, "Latitud":latf, "Longitud":longf,"Velocidad":velf,"Altura":heightf, "dt":dt }
    
    
    return datosf

# %% [markdown]
# <div style="text-align: justify">Para la funcion aceleracion, se utilizara una funcion de fitro gaussiano la cual tiene como entrada la velocidad, el delta de tiempo o intervalo de tiempo de un dato a otro y el filtro, entre mayor el numero del filtro mayor se suaviza el ruido de la funcion para encontrar la aceleracion. Las demas funciones como velocidad angular, potencia y torque ya fueron definidas en el taller anterior con el mismo modelo dinamico. </div>

# %%
def accel(vx, ddt,sigma):
    return ndimage.gaussian_filter1d(vx, sigma, order=1, mode='wrap') / ddt

# %%
def omega(vx):
    x=(vx*ng)/refc

    return x # (rad/s)



def potencia(vx):
    o=omega(vx)
    omega1=o*(60/(2*pi))
    P=torque(vx)*omega1

    return P

def torque(vx, ax):
    vk=vx*(3600/1000)
    
    T=((((ax)*(masa+mr))+frc(vk)+farrastre(vx))*(1/ng*etaf)*refc)
    return T

def frodadura(vx):
    wr=w*((a/l)+(ax/g*(h/l))) # fuerza vertical sobre las llantas tractivas
    fr=0.01*(1+(vx/100.0)) # Factor de rodadura la velocidad del kart debe estar en (km/h)
    # fr=C*((mllt*g)/(rllt*2))*sqrt(ht/bllt)
    # ht=0.0739 # Altura del neumático (m)
    # bllt=0.209 # Ancho del neumático (m)
    # C= # Constante del material de la llanta
    return wr*fr # (N)

def frc(vx):
    vk=vx*(3600/1000)
    fr=0.01*(1+(vx/100.0)) # Factor de rodadura la velocidad del kart debe estar en (km/h)
    return w*fr # (N)

def farrastre(vx):
    return (0.5)*rho*af*cd*(vx)**2 # (N)

def ftraccion(ax,Fg,Fw,Fr):
    
    return masa*ax+Fg+Fw+Fr

# %% [markdown]
# <div style="text-align: justify"> La funcion acelyvel es una de las mas importantes de esta seccion, la funcion de esta funcion es definir todas las caracteristicas de Kart, en terminos de la ruta recorrida, la grafica de velocidad como funcion del tiempo, la aceleracion como funcion del tiempo, la distancia de todo el recorrido, la velocidad maxima y la aceleracion como entrada. La entrada de la funcion es la carpeta y nombre del archivo ya que utiliza la funcion cortar datos; tambien le entran 2 numero i0 e i1 como el numero de inicio y final de la lista y por ultimo electricoocombustion es un numero entre 1 y 2 (1 si los datos son electricos y 2 si son de combustion) debido a que de esta forma el filtro gaussiano para la aceleracion cambia. El filtro es mas fuerte para los datos de combustion. El valor de este filtro fue elegido de maner arbitaria, cordoba utilizo un valor de 20 para los datos de combustion tambien. </div>

# %%
def acelyvel(carpeta,base,i0,i1,electricocombustion):
    
    #para electricocombustion= 1 es electrico y 2 es mecanico
    c=cortardatos(carpeta,base,i0,i1)
    figure(figsize(15,5))
    plt.subplot(1,3,1 )
    plot(c['Longitud'],c['Latitud'])
    plt.xlabel('Longitud (s)')
    plt.ylabel('Latitud (m/s)')
    plt.grid()
    
    plt.subplot(1,3,2)
    plot(c['Tiempo'],c['Velocidad'])
    plt.xlabel('t (s)')
    plt.ylabel('Velocidad(m/s)')
    plt.grid()
    
    
    plt.subplot(1,3,3)
    
    if electricocombustion==1:
        a=accel(c['Velocidad'],c['dt'],12 )
        plt.plot(c['Tiempo'],a)
        plt.xlabel('t (s)')
        plt.ylabel('Aceleracion(m/s^2)')
        plt.grid()
        plt.show()
    
    else:
        a=accel(c['Velocidad'],c['dt'],20 )
        plt.plot(c['Tiempo'],a)
        plt.plot(c['Tiempo'],a)
        plt.xlabel('t (s)')
        plt.ylabel('Aceleracion(m/s^2)')
        plt.grid()
        
    
    tiempodevuelta=np.max(c['Tiempo'])
    mensaje='el tiempo de vuelta es',tiempodevuelta
    vmax=np.max(c['Velocidad'])
    mensaje1='la velocidad maxima es',vmax
    amax=np.max(a)
    mensaje2='la aceleracion instantanea maxima es igual a',amax
    
    return mensaje,mensaje1,mensaje2

# %%
acelyvel('Data','VBOX0020.VBO',30,5500,2)
# Out:
# (('el tiempo de vuelta es', 54.690000000002328),
#  ('la velocidad maxima es', 25.031111111111112),
#  ('la aceleracion instantanea maxima es igual a', 3.5396927200947763))

# %% [markdown]
# Por ultimo, la funcion TyP. Esta funcion tambien es una de las mas importantes del taller. Esta funcion tiene como entrada las mismas variables que la funcion acelyvel (carpeta y nombre del arhivo, el numero inicial y final de datos y el valor 1 y 2 para electroocombustion). La funcon retora la grafica de torque contra tiempo, velocidad contra tiempo, potencia contra tiempo y torque contra velocidad angular.

# %%
def TyP(carpeta,base,i0,i1,electricocombustion):
    #para electricocombustion= 1 es electrico y 2 es mecanico
    c=cortardatos(carpeta,base,i0,i1)
    o=omega(c['Velocidad'])
    
    
    if electricocombustion==1:
        a=accel(c['Velocidad'],c['dt'],10)
        t=torque(c['Velocidad'],a)
    
    
    else:
        a=accel(c['Velocidad'],c['dt'],20)
        t=torque(c['Velocidad'],a)
    
    
    P=t*o
    
    figure(figsize(19,14))
    plt.subplot(2,3,1)
    plot(c['Tiempo'],t)
    plt.xlabel('t (s)')
    plt.ylabel('Torque(N*m)')
    plt.grid()
    plt.subplot(2,3,2)
    plot(c['Tiempo'],o)
    plt.xlabel('t (s)')
    plt.ylabel('Velicidad angular(rad/s)')
    plt.grid()
    plt.subplot(2,3,3)
    plot(c['Tiempo'],P)
    plt.xlabel('t (s)')
    plt.ylabel('Potencia (W)')
    plt.grid()
    plt.subplot(2,3,(4,6))
    plot(o,t)
    plt.xlabel('Velocidad angular(rad/s)')
    plt.ylabel('Torque (N*m)')
    plt.grid()
    tt=np.max(t)
    mensaje=' El Torque maximo es igual a',tt
    oo=np.max(o)
    mensaje1='La velocidad maxima es igual a',oo
    pp=np.max(P)
    mensaje2='La Potencia maxima entregada por el motor es igual a',pp
    
    return mensaje,mensaje1,mensaje2

# %%
TyP('data_electrico','VBS__047.VBO',370,1590,1)
# Out:
# ((' El Torque maximo es igual a', 18.494355928560797),
#  ('La velocidad maxima es igual a', 603.90833900597511),
#  ('La Potencia maxima entregada por el motor es igual a', 5821.5929347776864))

# %% [markdown]
# # Analisis #
# Por iteracion, se eligio los archivos con los resultados que parecieran mas confiable y los datos de inicio y final se eligio a prueba y error. Para el carro de combusion se eligio el archivo VBOX20 y para el electrico el VBS47.
#
# Los datos del rendimiento del kart de combustion:

# %%
acelyvel('Data','VBOX0020.VBO',30,5500,2)
# Out:
# (('el tiempo de vuelta es', 54.690000000002328),
#  ('la velocidad maxima es', 25.031111111111112),
#  ('la aceleracion instantanea maxima es igual a', 3.5396927200947763))

# %% [markdown]
# Los datos del rentimiento del kart electrico:

# %%
acelyvel('data_electrico','VBS__047.VBO',360,1590,1)
# Out:
# (('el tiempo de vuelta es', 61.450000000004366),
#  ('la velocidad maxima es', 23.202777777777779),
#  ('la aceleracion instantanea maxima es igual a', 1.88138183888844))

# %% [markdown]
# A continuacion se presentan los resultados de tiempo de vuelta en, aceleracion y velocidad maxima en una tabla:
#
# | Kart                       | Combustion | Electrico |
# |----------------------------|------------|-----------|
# | Tiempo de vuelta (s)       | 54.7       | 61.5      |
# | Velocidad max( m/s)        | 25.1       | 23.2      |
# | Aceleración maxima (m/s^2) | 3.5        | 1.9       |
#
# <div style="text-align: justify"> Como podemos ver de la table el rendimiento del motor de combustion es mucho mejor que el del kart electrico. Por ejempo, el tiempo de vuelta del kart de combustion es mucho menor al electrico aun cuando en la grafica de latitud y longitud se ve que el kart de combustion recorre una distancia mayor. Por otro lado, la vmax y amax del carro de combustion tambien es mayor en un 8% y un 45% respectivamente. Se puede asumir entonces que en el analisis a continuacion, el motor de combustion interna sera un motor de mayor desempeño y capacidad que el electrico y por lo tanto entregara un torque y potencia mayor. </div>
#
# A contuacion se presenta el desempeño del motor del kart de combustion:

# %%
TyP('Data','VBOX0020.VBO',30,5500,2)
# Out:
# ((' El Torque maximo es igual a', 27.269985607182278),
#  ('La velocidad maxima es igual a', 651.4951304262712),
#  ('La Potencia maxima entregada por el motor es igual a', 13059.765255860206))

# %% [markdown]
# Los datos del motor electrico:

# %%
TyP('data_electrico','VBS__047.VBO',370,1590,1)
# Out:
# ((' El Torque maximo es igual a', 18.494355928560797),
#  ('La velocidad maxima es igual a', 603.90833900597511),
#  ('La Potencia maxima entregada por el motor es igual a', 5821.5929347776864))

# %% [markdown]
# A continuacion se presenta una tabla con los resultados:
#
# | Kart                      | Combustion | Electrico |
# |---------------------------|------------|-----------|
# | Torque (N*m)              | 27.3       | 16.5      |
# | Velocidad Angular (rad/s) | 651.5      | 510       |
# | Potencia (W)              | 13060      | 5822      |
#
#
# <div style="text-align: justify"> Para empezar, podemos ver una fuente de error en los datos del kart electrico. Alrededor de los 57 segundo el torque y la velocidad angular se disparan. Probablemente se golpeo el VBOX o hubo alguna interferencia. Por esta fuente de error los datos de torque maximo y velocidad angular no pueden ser calculados por la funcion np.max sino por el contrario toca estimarlo con la grafica. </div>
#
# <div style="text-align: justify"> Continuando con el analisis, como se concluyo en el rendimiento del kart, era de esperarse que el el desempeño del motor dee combustion sea mucho mejor que el electrico. Como podemos ver, el motor de combustion entrega alrededor de casi 9 N*m al carro que el motor de combustion. En terminos de la velocidad angular, el motor de combustion rota alrededor de 1400 rpm mas rapido. Por ultimo, la potencia instantanea del motor de combustion es casi el doble que el electrico. El motor electrico es superado en todas las caracteristicas.</div>
#
# <div style="text-align: justify">Entre los errores que pueden afectar la diferencia en los resultados finales esta el filtro utilizado en la funcion de aceleracion, debido a que los datos electricos tienen mas ruido es necesario un filtro mas alto que puede afectar los valores de aceleracio (aun asi puede que no afecte tanto el resultado).</div>
#
# <div style="text-align: justify">Por ultimo, la grafica torque contra velocidad angular busca mostrar la curva caracteristica de cada motor. De la grafica de motor de combustion se puede ver como el motor tiende a seguir esa curva ideal donde el torque maximo tiene lugar en algun lugar angular (cerca de la mitad de la velocidad angular que toma em motor) y donde el torque es cero en velocidad angular cero (esta parte no es tan notorio en la grafica). Por otro lado, la grafica torque contra velocidad angular del motor electrico no esta tan definida. Aun asi se puede ver que, a velocidad angular igual a cero la curva no tiende a empezar en un torque cero sino por el contrario debe empezar a un valor de torque definido y a velocidades mas altas, el torque entregado si disminuye (caracteristicas de las curvas de motores electricos).</div>

# %% [markdown]
# ## Conclusiones ##
#
# - El desempeño del kart de combustion es mejor en terminos de velocidad lineal maxima y aceleracion instantanea comparado con el kart electrico.
# - El motor de combustion interna tiene un desempeño mejor que el motor electrico en terminos de torque, velocidad angular maxima y potencia entregada.
# - En este caso, aunque se espera que los 2 kart funcionaron bajo las mismas condiciones, no se sabe de manera contundente si esta afirmacion es verdad en terminos como masa del conductor, coeficiente de arrastre y relacion de transmision que como se vio en el taller 2 pueden afectar bastante el desempeño del motor.
# - De las graficas de torque contra velocidad angular se comprueba que los motores se comportan de manera esperada en terminos de motor de combustion y motor electrico respectivamente.
# - Por ultimo, si se espera mejorar el desempeño del kart electrico probablemente es necesario comprar un motor de mejor capacidad y entrega de torque.
# - Otra caracteristica que no es tomada en cuenta la autonomia de los carroes electricos el cual es un problema en la actualidad y por lo tanto debe ser tomado en cuenta al analizar un motor electrico o buscar comprar uno.
